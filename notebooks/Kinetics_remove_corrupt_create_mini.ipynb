# %%
import torch, torchvision
from torchvision.datasets.video_utils import VideoClips
import os, json
import numpy as np
from torch.utils.data import Dataset, DataLoader
import ffmpeg
from collections import Counter as C

# %%
class prober_class(Dataset):
    def __init__(self, paths):
        super(prober_class, self).__init__()
        self.paths = paths

    def __len__(self):
        return len(self.paths)
    
    def __getitem__(self, idx):
        k,p = self.paths[idx]
        try:
            res = ffmpeg.probe(p)
        except:
            res = "Error"
        
        return [res, k]

# %%
basepath = '/data/datasets/kinetics700_2020/'

def read_dataset_details(label_path, batch_size, vid_path):
    dataset = json.load(open(basepath + label_path))
    print(list(dataset.items())[0], len(dataset))
    collate = lambda x: x
    loader = DataLoader(prober_class([(k, basepath + vid_path + k + '.mp4') for k, v in dataset.items()]),
                         batch_size=batch_size,
                         num_workers=batch_size,
                         collate_fn=collate)
    print("Example paths:", loader.dataset.paths[:3])
    probes = []
    for i,batch in enumerate(loader):
        if i % 50 == 0:
            print(i*batch_size,'/',len(dataset))
        for b in batch:
            probes.append(b)
    print(C([type(p[0]) for p in probes]))
    return probes

# %%
def filter_dataset(label_path, probes):
    dataset = json.load(open(basepath + label_path))
    print(list(dataset.items())[0], len(dataset))
    
    new_dataset = {}
    error_remove_ids = []
    stream_err_ids = []

    for p, k in probes:
        if p == "Error":
            error_remove_ids.append(k)
        elif len(p['streams']) != 2:
            stream_err_ids.append(k)
        else:
            dataset[k]['nb_frames'] = p['streams'][0]['nb_frames']
            dataset[k]['hw'] = (p['streams'][0]['height'], p['streams'][0]['width'])
            dataset[k]['true_duration'] = p['streams'][0]['duration']
            new_dataset[k] = dataset[k]
            
    return new_dataset, error_remove_ids, stream_err_ids

# %%
probess = read_dataset_details('labels/val_full.json', 50, 'val/')
# Out:
# ('---QUuC4vJs', {'annotations': {'label': 'testifying', 'segment': [84.0, 94.0]}, 'duration': 10.0, 'subset': 'validate', 'url': 'https://www.youtube.com/watch?v=---QUuC4vJs'}) 34077
# Example paths: [('---QUuC4vJs', '/data/datasets/kinetics700_2020/val/---QUuC4vJs.mp4'), ('--GkrdYZ9Tc', '/data/datasets/kinetics700_2020/val/--GkrdYZ9Tc.mp4'), ('--nQbRBEz2s', '/data/datasets/kinetics700_2020/val/--nQbRBEz2s.mp4')]
# 0 / 34077
# 2500 / 34077
# 5000 / 34077
# 7500 / 34077
# 10000 / 34077
# 12500 / 34077
# 15000 / 34077
# 17500 / 34077
# 20000 / 34077
# 22500 / 34077
# 25000 / 34077
# 27500 / 34077
# 30000 / 34077
# 32500 / 34077
# Counter({<class 'dict'>: 32733, <class 'str'>: 1344})

# %%
new_dataset, error_remove_ids, stream_err_ids = filter_dataset('labels/val_full.json', probess)
# Out:
# ('---QUuC4vJs', {'annotations': {'label': 'testifying', 'segment': [84.0, 94.0]}, 'duration': 10.0, 'subset': 'validate', 'url': 'https://www.youtube.com/watch?v=---QUuC4vJs'}) 34077

# %%
json.dump(new_dataset, open(basepath + 'labels/val.json', 'w+'), indent=2)

# %%
probess = read_dataset_details('labels/train_full.json', 60, 'train/')
# Out:
# ('---0dWlqevI', {'annotations': {'label': 'clay pottery making', 'segment': [19.0, 29.0]}, 'duration': 10.0, 'subset': 'train', 'url': 'https://www.youtube.com/watch?v=---0dWlqevI'}) 541621
# Example paths: [('---0dWlqevI', '/data/datasets/kinetics700_2020/train/---0dWlqevI.mp4'), ('---aQ-tA5_A', '/data/datasets/kinetics700_2020/train/---aQ-tA5_A.mp4'), ('---j12rm3WI', '/data/datasets/kinetics700_2020/train/---j12rm3WI.mp4')]
# 0 / 541621
# 3000 / 541621
# 6000 / 541621
# 9000 / 541621
# 12000 / 541621
# 15000 / 541621
# 18000 / 541621
# 21000 / 541621
# 24000 / 541621
# 27000 / 541621
# 30000 / 541621
# 33000 / 541621
# 36000 / 541621
# 39000 / 541621
# 42000 / 541621
# 45000 / 541621
# 48000 / 541621
# 51000 / 541621
# 54000 / 541621
# 57000 / 541621
# 60000 / 541621
# 63000 / 541621
# 66000 / 541621
# 69000 / 541621
# 72000 / 541621
# 75000 / 541621
# 78000 / 541621
# 81000 / 541621
# 84000 / 541621
# 87000 / 541621
# 90000 / 541621
# 93000 / 541621
# 96000 / 541621
# 99000 / 541621
# 102000 / 541621
# 105000 / 541621
# 108000 / 541621
# 111000 / 541621
# 114000 / 541621
# 117000 / 541621
# 120000 / 541621
# 123000 / 541621
# 126000 / 541621
# 129000 / 541621
# 132000 / 541621
# 135000 / 541621
# 138000 / 541621
# 141000 / 541621
# 144000 / 541621
# 147000 / 541621
# 150000 / 541621
# 153000 / 541621
# 156000 / 541621
# 159000 / 541621
# 162000 / 541621
# 165000 / 541621
# 168000 / 541621
# 171000 / 541621
# 174000 / 541621
# 177000 / 541621
# 180000 / 541621
# 183000 / 541621
# 186000 / 541621
# 189000 / 541621
# 192000 / 541621
# 195000 / 541621
# 198000 / 541621
# 201000 / 541621
# 204000 / 541621
# 207000 / 541621
# 210000 / 541621
# 213000 / 541621
# 216000 / 541621
# 219000 / 541621
# 222000 / 541621
# 225000 / 541621
# 228000 / 541621
# 231000 / 541621
# 234000 / 541621
# 237000 / 541621
# 240000 / 541621
# 243000 / 541621
# 246000 / 541621
# 249000 / 541621
# 252000 / 541621
# 255000 / 541621
# 258000 / 541621
# 261000 / 541621
# 264000 / 541621
# 267000 / 541621
# 270000 / 541621
# 273000 / 541621
# 276000 / 541621
# 279000 / 541621
# 282000 / 541621
# 285000 / 541621
# 288000 / 541621
# 291000 / 541621
# 294000 / 541621
# 297000 / 541621
# 300000 / 541621
# 303000 / 541621
# 306000 / 541621
# 309000 / 541621
# 312000 / 541621
# 315000 / 541621
# 318000 / 541621
# 321000 / 541621
# 324000 / 541621
# 327000 / 541621
# 330000 / 541621
# 333000 / 541621
# 336000 / 541621
# 339000 / 541621
# 342000 / 541621
# 345000 / 541621
# 348000 / 541621
# 351000 / 541621
# 354000 / 541621
# 357000 / 541621
# 360000 / 541621
# 363000 / 541621
# 366000 / 541621
# 369000 / 541621
# 372000 / 541621
# 375000 / 541621
# 378000 / 541621
# 381000 / 541621
# 384000 / 541621
# 387000 / 541621
# 390000 / 541621
# 393000 / 541621
# 396000 / 541621
# 399000 / 541621
# 402000 / 541621
# 405000 / 541621
# 408000 / 541621
# 411000 / 541621
# 414000 / 541621
# 417000 / 541621
# 420000 / 541621
# 423000 / 541621
# 426000 / 541621
# 429000 / 541621
# 432000 / 541621
# 435000 / 541621
# 438000 / 541621
# 441000 / 541621
# 444000 / 541621
# 447000 / 541621
# 450000 / 541621
# 453000 / 541621
# 456000 / 541621
# 459000 / 541621
# 462000 / 541621
# 465000 / 541621
# 468000 / 541621
# 471000 / 541621
# 474000 / 541621
# 477000 / 541621
# 480000 / 541621
# 483000 / 541621
# 486000 / 541621
# 489000 / 541621
# 492000 / 541621
# 495000 / 541621
# 498000 / 541621
# 501000 / 541621
# 504000 / 541621
# 507000 / 541621
# 510000 / 541621
# 513000 / 541621
# 516000 / 541621
# 519000 / 541621
# 522000 / 541621
# 525000 / 541621
# 528000 / 541621
# 531000 / 541621
# 534000 / 541621
# 537000 / 541621
# 540000 / 541621
# Counter({<class 'dict'>: 523149, <class 'str'>: 18472})

# %%
json.dump(probess, open("tmp.json", 'w+'))

# %%
new_dataset, error_remove_ids, stream_err_ids = filter_dataset('labels/train_full.json', probess)
# Out:
# ('---0dWlqevI', {'annotations': {'label': 'clay pottery making', 'segment': [19.0, 29.0]}, 'duration': 10.0, 'subset': 'train', 'url': 'https://www.youtube.com/watch?v=---0dWlqevI'}) 541621

# %%
len(new_dataset)
# Out:
# 523099

# %%
len(error_remove_ids)
# Out:
# 18472

# %%
json.dump(error_remove_ids, open("corrupt_missing_train.json", 'w+'))

# %%
json.dump(stream_err_ids, open("stream_err_train.json", 'w+'))

# %%
json.dump(['xsGtbUnp9tw', '141fJ89Ed2k', 'q-S0pBZDhZU', 'wN8qYmPv5yk',
           'uz6rjbw0ZA0', 'kUVnT7Ld80M', 'XY5FDVay5_A', 'bOU2oGVBM_o',
           'fg2BS7H_dAU', 'KTCQpjUrCe8', 'erh2ngRZxs0', '7hIAtSLdAUo',
           'h_5SZwWFg1c', 'z8qEtdr1ZuU', 'VYZPozZ5Eig', '6iuD3pSgBcw',
           'NPNP-7B9P3M', 'yhA_TTKetyM', 'YjUcA9zOp5g', 'hKqCUWTQQxU'
          ],
         open("download_err_corrupt.json", 'w+')
        )

# %%
len(new_dataset)
# Out:
# 523099

# %%
json.dump(new_dataset, open(basepath + 'labels/train.json', 'w+'), indent=2)

# %%
# Create mini kinetics train
import random
label_class = list(set(m['annotations']['label'] for m in new_dataset.values()))
assert len(label_class) == 700
classwise_keys = {l:[] for l in label_class}
for k, d in new_dataset.items():
    classwise_keys[d['annotations']['label']].append(k)

# %%
classwise_ixs['sword swallowing']
# Out:
# ['-64SFG45MGc',
#  '-IRZQEPpXm4',
#  '-J6e6tmHfG0',
#  '-PH-LmbbhTs',
#  '-UkYLBqAIhM',
#  '-Zjg_1gu_iU',
#  '-eSjkYVfhkc',
#  '0-jShm5vXTs',
#  '0BQ1igghWA0',
#  '0HZwle1ARew',
#  '0Lkbe_-r6pM',
#  '0NiufOLGoA0',
#  '0XnSZRQzqK8',
#  '0_yEEH9mR40',
#  '0aS8cRgtAy4',
#  '0jADsepo9YU',
#  '0nK8obdz-R0',
#  '0nXW_392t7U',
#  '0q3gxEunti4',
#  '0ttcKxfMkIY',
#  '0tzXnhl9fL8',
#  '1CHOhK5iVnA',
#  '1YDQ9VFRuqQ',
#  '1aOvJdnUd4c',
#  '1c9XeAWUPPc',
#  '1eO0VT5JN_Q',
#  '1sVnKLmEL6A',
#  '1tO_esc3Sm4',
#  '1ymLC3bM9MY',
#  '1zX-Z5-fgF0',
#  '2FB3lFEsuIg',
#  '2FVCBPcpqEM',
#  '2ITyO3EZQkM',
#  '2dnQQNf-5Ik',
#  '2x8m37BjkzQ',
#  '36VCcm5hDJs',
#  '3K2aLO6QQt4',
#  '3hVgN5i6S4A',
#  '3lg6sjV9uf4',
#  '3wR1k8zQnck',
#  '45b037tFguk',
#  '4AsWlBRzJV4',
#  '4AubXyZXBto',
#  '4YY7xYlIbOE',
#  '4brLLAO3l50',
#  '4y41ZJjdleA',
#  '548No4eOFpY',
#  '5I98U_mxpJg',
#  '5_3YjiUqeRY',
#  '5yirj3QZKfU',
#  '5zDKDX18o9I',
#  '60_xGlF735w',
#  '65TtkqJFPqc',
#  '6C2LasQ5ep8',
#  '6M1k0XdiK7c',
#  '6O0LyhSqymY',
#  '6_cw1bhWdcQ',
#  '6xPf0z-A_gM',
#  '6zP7J6weGjc',
#  '6zrClfiSoDk',
#  '72gfy8QN1Ag',
#  '79l5AyYTdQM',
#  '7_ryhFxmXSs',
#  '8-WZxcCpei0',
#  '8843zgJgAnk',
#  '8NSi735_3dY',
#  '8P22FzqA6ns',
#  '8QCudwoWVe0',
#  '8RrR_tC_SuU',
#  '8TGQT0nFJjY',
#  '8UMdMBVmoSY',
#  '8lPvc0TYRZs',
#  '8nQYTqqipkU',
#  '8sxnNOHTdH8',
#  '9O4nTiq3kYI',
#  '9SKoJ7Hdtcw',
#  '9ckhWlZ97gE',
#  '9gcfZ8bnh-0',
#  '9lFNlMCxEZg',
#  '9lfXC-uTTec',
#  '9umVW6TTS80',
#  '9w9wdEvTAr4',
#  'A8Ncazh_kR8',
#  'ARHPyeCT3wQ',
#  'AT5saFLqhSU',
#  'AVoOx3QfISc',
#  'AWv9-onsclU',
#  'AaPcz4d-z78',
#  'AcSSciDCaRg',
#  'AokEaNXL968',
#  'Aral5D9i9bI',
#  'B-CBDoKD04E',
#  'B1OgHtI04VI',
#  'B1S42osgNi4',
#  'B6PyyZ-qyrw',
#  'BC6FSuOx6PA',
#  'BIP7eSgRzCE',
#  'BQlQJeOW0Hw',
#  'BRBHqLdIzrQ',
#  'BRj3RIfGl9Y',
#  'BV_B4xl0BEw',
#  'C0EwNG3QGBA',
#  'C2R-FiwrY2I',
#  'C4P_1O-A4XI',
#  'CCMzt0hl5O4',
#  'CGkoxBKGrM4',
#  'CMtt5wYtX5g',
#  'CPI3Sy0Ic54',
#  'CtzFLp30BoQ',
#  'CxvgSocH5OI',
#  'D0KwubYfSUs',
#  'DIKvQTYbwIg',
#  'DXdkiu2Ru2M',
#  'DfzQ8z8LFjc',
#  'DtehhhXFPu4',
#  'DuksfCKnb4k',
#  'E8ULp19Qw7I',
#  'EDl538BSLpk',
#  'EJN6C0SAQ6Y',
#  'EPc6wV57lE8',
#  'ETJ22pTTG-I',
#  'EaiU87xZUAY',
#  'EbOw-VUvxHE',
#  'EbRWEz6Pr8o',
#  'Ef_KZStxn1M',
#  'EsNyimK5dhg',
#  'F6_MlFyElpc',
#  'FPY8__-P0CY',
#  'FPo_XHf-xx8',
#  'FeJeKAMHEjQ',
#  'FwJULbLlMbI',
#  'Fzk582quk_k',
#  'GDMGYsgyDRk',
#  'GH4Mdee5ljw',
#  'GTi9ztmGTlA',
#  'GVDGIhSsHVc',
#  'GYeJXnvejn4',
#  'Gas_qfXIHaA',
#  'Gwg2aUDSmkQ',
#  'GyLh_GP50RE',
#  'H26Rg2fE93k',
#  'H67RqaLLrzo',
#  'HBn-pCHCKlY',
#  'HCdNuqmQUxI',
#  'HCerfQmyRGU',
#  'HEF9TzmV7T4',
#  'HFmwmkdcV1M',
#  'HMDU_6blezA',
#  'HMRSf7WV67A',
#  'HSlLw_mkz_8',
#  'HpgQ2YJh3wg',
#  'HuoVeY0vBgU',
#  'I3YTkDPh-34',
#  'I5QRDKisoP4',
#  'IJkuZCpn9sI',
#  'IRj_Bn2kF4U',
#  'IUgiXEB7p4E',
#  'IZhYJj8ovpc',
#  'J6Pb986-51I',
#  'JOpzDjxQ1JI',
#  'JVoLGsbwVBY',
#  'Jn9m7w1-eGk',
#  'KNOZnQhAEqM',
#  'KRSw2z-C2nw',
#  'K_t04Vg8mHM',
#  'Kc7zieh7V5A',
#  'Ki7vOkgJtOA',
#  'Kp2LzSd1xI4',
#  'KuBs_EszuIg',
#  'L67xfPT8zuQ',
#  'LD0pjYqil0s',
#  'LPqkFoScyu4',
#  'LQO9v4d8Q2E',
#  'LddHmccwMMs',
#  'LivXr9pGc6g',
#  'LmRPRNw9cgI',
#  'MVFcxo-Pnq8',
#  'Mlf8f5CHmzU',
#  'Mn_nkQJmJiE',
#  'MrMz2cH1OlY',
#  'Ms6xNOVfjWg',
#  'N1JN_9qL24Y',
#  'N8BiWp5wao8',
#  'NLvzrLD5fTQ',
#  'NTCbYlWBL1U',
#  'NYyEv8RnSSE',
#  'NhFhgJIEAEY',
#  'NkCaG0-x8kY',
#  'NpvF_KvpN3I',
#  'NqhFNr9ToBc',
#  'NzHlipws6xI',
#  'O-UeDwjjjyY',
#  'OPKgx856GyQ',
#  'OX5lxmqInkM',
#  'OYmM8QmEAUM',
#  'OaEDY3WJYt0',
#  'OglCujWq1sM',
#  'Osxp6d9ZJRc',
#  'P41p3HnkiFk',
#  'PGKybjjUDdE',
#  'PRasaltMy3Y',
#  'Pejt2BJFgkw',
#  'Ps36jHbFlKw',
#  'QEAchum1u9U',
#  'QPVz7wIgUxU',
#  'QSppyPDaEI8',
#  'QV35mzXU-ew',
#  'QVZ7VoCdF-Y',
#  'QXlohX5T_hM',
#  'QaUg7ucTWMQ',
#  'QgT8hPX0zao',
#  'Qq5z1RoG7f8',
#  'QuV8oaoUzBE',
#  'RKTOBQM_oeI',
#  'RMYAghMmkQA',
#  'RtJBqwNHBKY',
#  'RukJcjRsIrI',
#  'Rx8Ou2RYjgw',
#  'RyysR3pTprk',
#  'S2mutLM_2ms',
#  'S6TVPuVqHRQ',
#  'S82vvlN0fbE',
#  'SOLpNp4zcaE',
#  'SQalFoyzcjQ',
#  'SWJc13NEZM0',
#  'ScKpLFR5QlA',
#  'SejcF2mpW_4',
#  'SqMixVjiA8U',
#  'SrT0VhGylzo',
#  'T9V27PeJcQw',
#  'TBtzj_1UFrQ',
#  'TTCrlKiX6Ew',
#  'TYvbQ6yliPw',
#  'TdEPcXpg-Os',
#  'ToXV9XR9OTw',
#  'Tppi02wJFJ8',
#  'TvaGDryF1Dg',
#  'Txi8tI9Yksk',
#  'UCwOc4pWuN0',
#  'UFBzT4RFFTU',
#  'URr60qql-gs',
#  'UcCH4Nx5zS8',
#  'UcpqV_8z4D4',
#  'Uh2xGPkBHYA',
#  'Un3dfYcy9Xo',
#  'UpuETK0okXQ',
#  'Ut0sRNBXcGQ',
#  'UyJjelweS2w',
#  'V23PvIz_F2k',
#  'V4qzpN1expA',
#  'V7SDPDzItq0',
#  'VKkkdL09gd0',
#  'VVJBGqpPznc',
#  'VWXZI1fUFKo',
#  'VaDu0sBjD9o',
#  'VqdAgehAs54',
#  'Vwt-dzJHqW4',
#  'VzHRTdDPddo',
#  'W5HefZdcPtM',
#  'WCYiPPxVp8A',
#  'WCa2nmdLT6w',
#  'We653mND2iQ',
#  'WrKDYOCihJU',
#  'Wy5o-hUGJEw',
#  'X4DqQwIhzC4',
#  'XIFgIq5EaIg',
#  'XKC5b9sY1gA',
#  'XNrevj4FYV8',
#  'XV12hZx14lo',
#  'XbJEHmg4sWA',
#  'Xeyk-34lyfw',
#  'Xm0f8sjbm9M',
#  'Y01cHXYYANg',
#  'YBlVYU4l01M',
#  'YnRLsmtUIgQ',
#  'YyVKqdEBBPw',
#  'Z-vxyMw2cKE',
#  'Z34HvlDNQYA',
#  'ZFbZVEpu_A4',
#  'ZLM7VmPykjE',
#  'ZcgbqrfNXFg',
#  'ZuyAoyYGWEE',
#  'Zx1D1l5lWyM',
#  '_IOqAd6ATss',
#  '_U_583oucWk',
#  '_uoWWYz6QZ0',
#  '_vsBM4NGCsI',
#  'a8awZGqie38',
#  'aFanl6PN_ck',
#  'aUPeolCs4LE',
#  'aV3_rvCu50k',
#  'aXCEECzthQ0',
#  'abIuyehc_qc',
#  'bGgG-z8XQj0',
#  'bGifKP_RdlI',
#  'bJnYbEamdw8',
#  'bkAO1C_0fYI',
#  'bm6y-xf7uR0',
#  'brRNGHK660o',
#  'c1YaTPvdw_E',
#  'c1dzIi6en6k',
#  'cYfX0D6nHOc',
#  'cuaaislFHGI',
#  'czAwq50QtJo',
#  'd1CJeQHm7S4',
#  'd2-GJpy8ePU',
#  'd5rl1_0Bx2E',
#  'd6hi6Ggv6_o',
#  'd7TUDqxJeLI',
#  'dKnEfjNCfUI',
#  'dW15DwtQIRE',
#  'dXCEBCt3K6Y',
#  'dvd3ljZZ99E',
#  'e539DUupRzA',
#  'eIAXmWj1PEc',
#  'eOqelCsp6jk',
#  'eRCkTIugZuk',
#  'eUbHt8KO6rc',
#  'egOotc7Lx5M',
#  'fZoPejoZh3w',
#  'fkalKEWcuPM',
#  'fmE-WhrLltk',
#  'fpFwMWrL2Uc',
#  'ftY70RZ-Saw',
#  'fxGn7Rk7oGY',
#  'gF9FA8FCRSA',
#  'gFCqfKXcmV8',
#  'gMlG6YbXPVw',
#  'gU0heiAlqb4',
#  'g_rESZyCtqs',
#  'gctIfr_0gOo',
#  'gmsEbLvEHkw',
#  'gtKmSGfYL30',
#  'h-QwCFf49Uo',
#  'hEeoFggQGYQ',
#  'hU-i-AT_JjY',
#  'hVsGDLapo9k',
#  'hYaH6anwTxw',
#  'hq9B2_z6yd0',
#  'htN5GjzxqyU',
#  'iBF-6c8JLUQ',
#  'iEe2AxoZ7SQ',
#  'iU3B-4ilwtc',
#  'igQDS3swxbw',
#  'iwhcT6QlYUU',
#  'j13UqZL6mAk',
#  'j7jIZHyuEzw',
#  'j9Ul3aTdEkw',
#  'jHcyNkqjXHc',
#  'jVPG3ice6Kk',
#  'jXmEmfChGJU',
#  'jgcXKCNy9wM',
#  'ji-LTAGhd8w',
#  'jl236b4rUQM',
#  'jrCJGWnEcnw',
#  'k4R_JWD0zK0',
#  'kNlV6Sv33Jg',
#  'kfIRPR7Jr-Y',
#  'kgAZd-RzvkQ',
#  'kv8pTm4UbJ0',
#  'kyo32lKkT-s',
#  'l5mEmY91pDc',
#  'l5qVWJ7A3H4',
#  'lFAmEp8aOMs',
#  'lFoYIjtUuFY',
#  'lGkSARyOSho',
#  'lIxdvo4VaEg',
#  'lO6U-uUhyIo',
#  'lTJ3L3KHE5U',
#  'lY9BAA3QCes',
#  'lm-6ZDFD3ZU',
#  'lsDmmtnxl2c',
#  'lvwp6mR32ac',
#  'm6ikGz4ZFEY',
#  'mFAw8RlU0Xo',
#  'mN6TyFTKQbQ',
#  'mSJDSFU6XXQ',
#  'mXujEe2YzfQ',
#  'mr7mgdPGuSE',
#  'mtvBbuOtO2c',
#  'mzWGSkskgK0',
#  'n-DZiOg90jA',
#  'nN3mDqUSBbI',
#  'nSV_WLl8mlg',
#  'n_LgnQej1Ao',
#  'nk5L_VoxmD0',
#  'nl54-7vEm9A',
#  'nzoB6roWpw4',
#  'o3okiG-lsxU',
#  'oBjB0Tj-zWo',
#  'oIjgxn670LM',
#  'oQBCIfmoKUo',
#  'oW0uJCeGhww',
#  'osHg8V0M8Qs',
#  'oup6SpZaBkk',
#  'p8TMz7pFhB4',
#  'pCvtUV70frw',
#  'pFVQVFrWg14',
#  'pMQJs9EsScY',
#  'pYV0hg6p_tk',
#  'pZ8Ut-KUigk',
#  'pdmPbB-ObiM',
#  'pfgr6LMFAoc',
#  'pkI19YshY40',
#  'prmuLw7esyA',
#  'pulCRVzLtoo',
#  'qBBHtcYieO0',
#  'qDnOvnSHuHM',
#  'qF0lF8k6LLI',
#  'qGLUjiLOxGs',
#  'qRUOPPHJzrg',
#  'qUjF3E8tEhI',
#  'qkCzvR72h6U',
#  'qlGFwi7dyBc',
#  'qpwOIp2JZrc',
#  'qrB6WnvZx1U',
#  'qscR3WhPSEM',
#  'qy9KNeBJnxw',
#  'r2y6-t92k4Y',
#  'r43LNy-UC3s',
#  'r8I9cfM1VT4',
#  'rL3E0hO1tdI',
#  'rTjOjbBmO2Y',
#  'rbYI0iLnvOY',
#  'rcoM9K-8V2c',
#  'rgPRWfFvJXk',
#  'rqkSbFY-wQc',
#  'rwppoyljOMM',
#  's-uuGdN0tbg',
#  's43uLxUlYes',
#  's9nBbCg3Fqc',
#  'sG0u5GHlYHg',
#  'sWjDz45QrFE',
#  'sfJVrnws_Uc',
#  'sj8ct_ZZ2Hs',
#  'swCP3jfw1OE',
#  'sy7NHIQfLDs',
#  'tGMrgK7v5Ps',
#  'tojCJwCfavo',
#  'ttF_FjQrX-w',
#  'u31lkPjMMG0',
#  'u3I7snbwxyM',
#  'u45u1FHxHFk',
#  'uJKrKdufpmA',
#  'uKNGwtD-lVA',
#  'uUSE-huL9rs',
#  'udng4UaeVNA',
#  'uuhRH1HJiIs',
#  'uze3IFOYfS8',
#  'v0k_zaqbpz0',
#  'v0rgf6cU7ls',
#  'v6SZUTDLNcg',
#  'vv8LAxmG-2M',
#  'vwbkN-SVpHQ',
#  'wBuGuRY50Eo',
#  'wCjR3qve8P0',
#  'wCnTNbvOoco',
#  'wJQznaXLO0Q',
#  'wVF5LEn94aE',
#  'wXAb1Q_zYww',
#  'w_Xvv40SUT0',
#  'wrrKKLEfN98',
#  'wuSS3VDYTrg',
#  'x-ICamH10vE',
#  'xVs6PHdrNt4',
#  'xeflsTXz-Zc',
#  'xfPnKVRJFhU',
#  'y5LRK42LJ84',
#  'yCFRe0Ph2es',
#  'yGTD24el2BY',
#  'yQY2LQ69zoE',
#  'ya4bS9OaKVc',
#  'yv7o-OgibhE',
#  'zCqHomSoOdY',
#  'zEyu0Y4RCEI',
#  'zX8WJT_T8y0',
#  'zXa7b-RhFuw',
#  'zcrur8hj3tk',
#  'zixsJF6FImM',
#  'zjngvbz7YRY']

# %%
mini_train = dict(random.sample(list(new_dataset.items()), 200000))

# %%
dict(sorted(C(m['annotations']['label'] for m in mini_train.values()).items(),key=lambda x: x[1]))
# Out:
# {'putting on sari': 160,
#  'sword swallowing': 174,
#  'combing hair': 176,
#  'flipping bottle': 178,
#  'playing nose flute': 187,
#  'dyeing eyebrows': 187,
#  'arresting': 188,
#  'shooting off fireworks': 189,
#  'closing door': 190,
#  'skiing mono': 191,
#  'coloring in': 192,
#  'cracking neck': 192,
#  'treating wood': 193,
#  'chasing': 193,
#  'chiseling wood': 195,
#  'doing jigsaw puzzle': 195,
#  'grinding meat': 195,
#  'saluting': 196,
#  'shredding paper': 196,
#  'listening with headphones': 197,
#  'mushroom foraging': 197,
#  'moving baby': 197,
#  'cracking back': 197,
#  'playing mahjong': 197,
#  'playing with trains': 198,
#  'smoking': 198,
#  'milking goat': 198,
#  'dealing cards': 199,
#  'petting horse': 200,
#  'carving wood with a knife': 200,
#  'pinching': 200,
#  'chiseling stone': 201,
#  'checking watch': 201,
#  'bouncing ball (not juggling)': 201,
#  'slicing onion': 202,
#  'swimming front crawl': 202,
#  'texting': 202,
#  'pouring milk': 203,
#  'being in zero gravity': 203,
#  'playing road hockey': 204,
#  'repairing puncture': 204,
#  'card stacking': 204,
#  'polishing furniture': 204,
#  'putting on eyeliner': 205,
#  'carrying weight': 205,
#  'grooming cat': 205,
#  'peeling banana': 205,
#  'playing slot machine': 206,
#  'playing dominoes': 206,
#  'blending fruit': 206,
#  'capsizing': 206,
#  'poking bellybutton': 206,
#  'sucking lolly': 206,
#  'coughing': 207,
#  'playing oboe': 207,
#  'massaging neck': 207,
#  'answering questions': 207,
#  'fixing bicycle': 208,
#  'surveying': 208,
#  'playing lute': 208,
#  'metal detecting': 209,
#  'cutting orange': 209,
#  'sieving': 210,
#  'cutting apple': 210,
#  'taking photo': 211,
#  'lighting candle': 211,
#  'uncorking champagne': 211,
#  'tiptoeing': 211,
#  'testifying': 211,
#  'playing piccolo': 211,
#  'mixing colours': 211,
#  'swimming with dolphins': 212,
#  'bending back': 212,
#  'delivering mail': 213,
#  'lighting fire': 213,
#  'sawing wood': 213,
#  'peeling potatoes': 213,
#  'cutting cake': 213,
#  'vacuuming car': 213,
#  'making horseshoes': 213,
#  'looking at phone': 213,
#  'wading through water': 214,
#  'gargling': 214,
#  'making slime': 214,
#  'crocheting': 215,
#  'sanding wood': 215,
#  'picking apples': 215,
#  'threading needle': 215,
#  'doing laundry': 215,
#  'squeezing orange': 215,
#  'putting on shoes': 215,
#  'staring': 215,
#  'geocaching': 216,
#  'base jumping': 216,
#  'putting wallpaper on wall': 216,
#  'poaching eggs': 216,
#  'pulling espresso shot': 216,
#  'tossing salad': 216,
#  'playing cards': 216,
#  'carving marble': 217,
#  'gospel singing in church': 217,
#  'sausage making': 217,
#  'baby waking up': 217,
#  'shopping': 217,
#  'making paper aeroplanes': 218,
#  'shoot dance': 218,
#  'hugging baby': 218,
#  'laying decking': 218,
#  'attending conference': 218,
#  'home roasting coffee': 218,
#  'ski jumping': 219,
#  'herding cattle': 219,
#  'curling eyelashes': 219,
#  'trimming shrubs': 219,
#  'filling cake': 219,
#  'alligator wrestling': 219,
#  'using a power drill': 220,
#  'playing field hockey': 220,
#  'assembling bicycle': 220,
#  'rolling pastry': 220,
#  'playing american football': 220,
#  'twiddling fingers': 220,
#  'massaging feet': 221,
#  'making a cake': 221,
#  'letting go of balloon': 221,
#  'changing gear in car': 221,
#  'docking boat': 221,
#  'ski ballet': 221,
#  'lifting hat': 221,
#  'breaking glass': 222,
#  'playing checkers': 222,
#  'tasting wine': 222,
#  'playing billiards': 222,
#  'peeling apples': 223,
#  'washing hair': 223,
#  'using atm': 223,
#  'looking in mirror': 223,
#  'smashing': 224,
#  'card throwing': 224,
#  'playing scrabble': 224,
#  'scrubbing face': 224,
#  'putting in contact lenses': 225,
#  'passing soccer ball': 225,
#  'recording music': 225,
#  'playing darts': 225,
#  'jumping bicycle': 225,
#  'fixing hair': 225,
#  'adjusting glasses': 226,
#  'using megaphone': 226,
#  'springboard diving': 226,
#  'tie dying': 227,
#  'playing blackjack': 227,
#  'photobombing': 227,
#  'using circular saw': 227,
#  'laying stone': 227,
#  'waxing back': 228,
#  'breading or breadcrumbing': 228,
#  'directing traffic': 228,
#  'applauding': 229,
#  'picking blueberries': 229,
#  'luge': 229,
#  'using a microscope': 229,
#  'applying cream': 229,
#  'entering church': 229,
#  'eating carrots': 229,
#  'using a paint roller': 229,
#  'ice swimming': 230,
#  'casting fishing line': 230,
#  'swinging baseball bat': 231,
#  'playing marbles': 231,
#  'using inhaler': 232,
#  'playing kickball': 232,
#  'sign language interpreting': 232,
#  'bulldozing': 232,
#  'arguing': 233,
#  'putting on mascara': 233,
#  'golf putting': 233,
#  'playing rounders': 234,
#  'flint knapping': 234,
#  'bobsledding': 234,
#  'using a wrench': 234,
#  'high fiving': 234,
#  'doing sudoku': 234,
#  'gold panning': 234,
#  'making cheese': 234,
#  'petting cat': 235,
#  'clam digging': 235,
#  'shouting': 236,
#  'being excited': 236,
#  'mosh pit dancing': 236,
#  'spraying': 236,
#  'building shed': 237,
#  'calculating': 237,
#  'eating nachos': 237,
#  'needle felting': 237,
#  'playing hand clapping games': 238,
#  'laying tiles': 238,
#  'square dancing': 238,
#  'moving child': 238,
#  'passing American football (in game)': 238,
#  'pouring wine': 238,
#  'kissing': 239,
#  'throwing water balloon': 239,
#  'spinning plates': 239,
#  'archaeological excavation': 239,
#  'seasoning food': 239,
#  'waxing eyebrows': 239,
#  'licking': 240,
#  'using bagging machine': 240,
#  'throwing tantrum': 240,
#  'swimming backstroke': 240,
#  'ironing hair': 240,
#  'playing laser tag': 241,
#  'tossing coin': 241,
#  'jaywalking': 241,
#  'chewing gum': 241,
#  'making latte art': 241,
#  'drooling': 242,
#  'massaging legs': 242,
#  'swimming with sharks': 242,
#  'punching person (boxing)': 242,
#  'stacking cups': 243,
#  'golf chipping': 243,
#  'dumpster diving': 243,
#  'playing shuffleboard': 243,
#  'making tea': 244,
#  'opening door': 244,
#  'huddling': 244,
#  'photocopying': 244,
#  'drumming fingers': 244,
#  'building lego': 245,
#  'lawn mower racing': 245,
#  'roasting pig': 245,
#  'walking with crutches': 245,
#  'cracking knuckles': 245,
#  "massaging person's head": 246,
#  'swimming butterfly stroke': 246,
#  'wading through mud': 247,
#  'rolling eyes': 247,
#  'pushing wheelbarrow': 247,
#  'planing wood': 247,
#  'opening refrigerator': 247,
#  'playing pan pipes': 247,
#  'massaging back': 248,
#  'marriage proposal': 248,
#  'extinguishing fire': 248,
#  'cleaning gutters': 248,
#  'playing rubiks cube': 248,
#  'scrapbooking': 249,
#  'popping balloons': 250,
#  'digging': 250,
#  'pumping gas': 250,
#  'waxing armpits': 251,
#  'shaving legs': 251,
#  'hand washing clothes': 251,
#  'chopping meat': 252,
#  'skipping stone': 252,
#  'brushing floor': 252,
#  'holding snake': 253,
#  'curling (sport)': 254,
#  'polishing metal': 254,
#  'riding mule': 254,
#  'cooking scallops': 254,
#  'land sailing': 255,
#  'watching tv': 256,
#  'pretending to be a statue': 256,
#  'stomping grapes': 256,
#  'setting table': 257,
#  'hockey stop': 257,
#  'splashing water': 258,
#  'bottling': 258,
#  'filling eyebrows': 258,
#  'making snowman': 258,
#  'decoupage': 258,
#  'unloading truck': 258,
#  'fidgeting': 258,
#  'shooting goal (soccer)': 258,
#  'burping': 259,
#  'laying bricks': 259,
#  'opening coconuts': 259,
#  'smelling feet': 260,
#  'getting a haircut': 260,
#  'helmet diving': 261,
#  'cumbia': 261,
#  'cleaning pool': 261,
#  'roasting marshmallows': 262,
#  'tackling': 262,
#  'standing on hands': 262,
#  'eating watermelon': 262,
#  'smoking pipe': 262,
#  'moving furniture': 262,
#  'fencing (sport)': 262,
#  'calligraphy': 262,
#  'parkour': 262,
#  'hoverboarding': 263,
#  'visiting the zoo': 263,
#  'playing polo': 264,
#  'carrying baby': 264,
#  'shining flashlight': 264,
#  'contorting': 264,
#  'playing controller': 265,
#  'bouncing on bouncy castle': 265,
#  'jogging': 265,
#  'wood burning (art)': 265,
#  'putting on foundation': 265,
#  'whistling': 265,
#  'climbing ladder': 266,
#  'throwing knife': 267,
#  'opening wine bottle': 267,
#  'shaking hands': 268,
#  'waiting in line': 268,
#  'blowing leaves': 269,
#  'separating eggs': 269,
#  'yoga': 270,
#  'talking on cell phone': 270,
#  'pirouetting': 271,
#  'pouring beer': 271,
#  'cooking on campfire': 271,
#  'steering car': 272,
#  'installing carpet': 272,
#  'skiing crosscountry': 272,
#  'weaving fabric': 273,
#  'cooking chicken': 273,
#  'waving hand': 273,
#  'using puppets': 273,
#  'yawning': 273,
#  'playing poker': 274,
#  'moon walking': 274,
#  'jumping sofa': 274,
#  'ice skating': 275,
#  'reading newspaper': 275,
#  'leatherworking': 275,
#  'tagging graffiti': 275,
#  'news anchoring': 276,
#  'winking': 276,
#  'tying bow tie': 276,
#  'falling off bike': 277,
#  'sharpening pencil': 277,
#  'shaping bread dough': 278,
#  'making bubbles': 278,
#  'bathing dog': 278,
#  'karaoke': 278,
#  'writing': 278,
#  'crossing eyes': 279,
#  'sewing': 279,
#  'building cabinet': 279,
#  'drawing': 279,
#  'throwing snowballs': 279,
#  'playing flute': 279,
#  'carving ice': 279,
#  'tickling': 280,
#  'rock scissors paper': 280,
#  'crying': 280,
#  'packing': 281,
#  'unboxing': 282,
#  'singing': 282,
#  'falling off chair': 283,
#  'walking on stilts': 283,
#  'playing gong': 283,
#  'blowdrying hair': 285,
#  'counting money': 285,
#  'petting animal (not cat)': 286,
#  'training dog': 286,
#  'steer roping': 286,
#  'playing bass guitar': 287,
#  'playing maracas': 287,
#  'tying shoe laces': 287,
#  'driving car': 287,
#  'washing feet': 288,
#  'checking tires': 289,
#  'headbutting': 289,
#  'riding elephant': 289,
#  'cleaning toilet': 289,
#  'tasting beer': 289,
#  'auctioning': 289,
#  'making a sandwich': 289,
#  'eating doughnuts': 289,
#  'playing basketball': 289,
#  'baking cookies': 290,
#  'juggling fire': 290,
#  'snorkeling': 290,
#  'exercising arm': 291,
#  'putting on lipstick': 291,
#  'bending metal': 292,
#  'dining': 292,
#  'eating hotdog': 292,
#  'windsurfing': 292,
#  'decorating the christmas tree': 293,
#  'sleeping': 294,
#  'catching or throwing softball': 294,
#  'shucking oysters': 294,
#  'playing monopoly': 295,
#  'sneezing': 295,
#  'yarn spinning': 295,
#  'playing ping pong': 296,
#  'disc golfing': 296,
#  'jumping jacks': 297,
#  'playing cymbals': 297,
#  'riding or walking with horse': 298,
#  'catching fish': 298,
#  'breathing fire': 299,
#  'cosplaying': 299,
#  'drinking shots': 299,
#  'laying concrete': 300,
#  'trimming trees': 300,
#  'walking through snow': 300,
#  'blowing nose': 300,
#  'tai chi': 300,
#  'tightrope walking': 301,
#  'barbequing': 301,
#  'waxing chest': 302,
#  'planting trees': 302,
#  'playing clarinet': 303,
#  'blowing bubble gum': 303,
#  'using a sledge hammer': 304,
#  'javelin throw': 304,
#  'cutting watermelon': 305,
#  'pushing car': 305,
#  'washing dishes': 307,
#  'playing netball': 307,
#  'playing cello': 307,
#  'acting in play': 307,
#  'throwing axe': 307,
#  'person collecting garbage': 307,
#  'trapezing': 308,
#  'silent disco': 308,
#  'sanding floor': 308,
#  'frying vegetables': 309,
#  'using segway': 309,
#  'playing beer pong': 309,
#  'using remote controller (not gaming)': 310,
#  'scrambling eggs': 310,
#  'drop kicking': 310,
#  'belly dancing': 311,
#  'egg hunting': 311,
#  'playing pinball': 311,
#  'making the bed': 312,
#  'carving pumpkin': 312,
#  'folding clothes': 313,
#  'playing ocarina': 313,
#  'jetskiing': 314,
#  'ice fishing': 314,
#  'backflip (human)': 316,
#  'blowing glass': 316,
#  'building sandcastle': 316,
#  'skateboarding': 317,
#  'getting a piercing': 318,
#  'bungee jumping': 318,
#  'hopscotch': 319,
#  'riding snow blower': 320,
#  'diving cliff': 320,
#  'feeding goats': 321,
#  'hitting baseball': 321,
#  'eating chips': 322,
#  'playing harmonica': 322,
#  'waxing legs': 322,
#  'stacking dice': 323,
#  'braiding hair': 323,
#  'playing guitar': 323,
#  'ripping paper': 323,
#  'milking cow': 323,
#  'making sushi': 323,
#  'grooming horse': 324,
#  'breaking boards': 324,
#  'fly tying': 324,
#  'mopping floor': 325,
#  'sweeping floor': 325,
#  'giving or receiving award': 325,
#  'playing cricket': 326,
#  'brush painting': 326,
#  'curling hair': 326,
#  'cooking egg': 326,
#  'historical reenactment': 327,
#  'hurdling': 327,
#  'sled dog racing': 327,
#  'clay pottery making': 327,
#  'country line dancing': 327,
#  'sipping cup': 327,
#  'catching or throwing frisbee': 327,
#  'cleaning shoes': 328,
#  'clean and jerk': 328,
#  'playing tennis': 328,
#  'riding a bike': 328,
#  'pulling rope (game)': 329,
#  'playing recorder': 329,
#  'swimming breast stroke': 330,
#  'embroidering': 331,
#  'kicking field goal': 331,
#  'scuba diving': 331,
#  'shaving head': 332,
#  'pushing wheelchair': 332,
#  'cutting nails': 332,
#  'tying necktie': 333,
#  'faceplanting': 333,
#  'walking the dog': 333,
#  'spelunking': 333,
#  'making jewelry': 333,
#  'pumping fist': 334,
#  'longboarding': 334,
#  'jumping into pool': 334,
#  'head stand': 335,
#  'tasting food': 336,
#  'running on treadmill': 336,
#  'waking up': 336,
#  'folding paper': 336,
#  'playing keyboard': 338,
#  'arranging flowers': 338,
#  'squat': 338,
#  'sharpening knives': 338,
#  'bodysurfing': 339,
#  'wrestling': 339,
#  'making balloon shapes': 340,
#  'kicking soccer ball': 340,
#  'eating burger': 340,
#  'dancing ballet': 340,
#  'cleaning windows': 340,
#  'preparing salad': 340,
#  'surfing crowd': 340,
#  'smoking hookah': 341,
#  'tap dancing': 341,
#  'blowing out candles': 341,
#  'ironing': 341,
#  'weaving basket': 341,
#  'blasting sand': 341,
#  'shooting basketball': 341,
#  'crawling baby': 342,
#  'dribbling basketball': 342,
#  'assembling computer': 342,
#  'arm wrestling': 343,
#  'clapping': 343,
#  'feeding fish': 343,
#  'playing accordion': 343,
#  'flying kite': 344,
#  'changing oil': 344,
#  'dyeing hair': 345,
#  'salsa dancing': 345,
#  'doing nails': 345,
#  'playing chess': 346,
#  'inflating balloons': 346,
#  'hugging (not baby)': 346,
#  'shuffling cards': 346,
#  'motorcycling': 346,
#  'rope pushdown': 347,
#  'changing wheel (not on bike)': 347,
#  'air drumming': 347,
#  'shot put': 347,
#  'eating ice cream': 348,
#  'playing harp': 348,
#  'pull ups': 348,
#  'welding': 348,
#  'climbing a rope': 349,
#  'passing American football (not in game)': 350,
#  'zumba': 350,
#  'punching bag': 351,
#  'spinning poi': 351,
#  'high jump': 351,
#  'juggling soccer ball': 351,
#  'exercising with an exercise ball': 352,
#  'pushing cart': 352,
#  'tango dancing': 352,
#  'making pizza': 352,
#  'beatboxing': 352,
#  'finger snapping': 352,
#  'archery': 352,
#  'playing trombone': 352,
#  'tapping pen': 353,
#  'deadlifting': 354,
#  'robot dancing': 354,
#  'pillow fight': 354,
#  'getting a tattoo': 354,
#  'laughing': 354,
#  'sticking tongue out': 354,
#  'bowling': 354,
#  'shearing sheep': 354,
#  'playing ukulele': 354,
#  'climbing tree': 355,
#  'feeding birds': 355,
#  'bouncing on trampoline': 355,
#  'grooming dog': 356,
#  'opening present': 356,
#  'lock picking': 356,
#  'shining shoes': 356,
#  'water skiing': 356,
#  'crossing river': 356,
#  'snowmobiling': 357,
#  'bee keeping': 357,
#  'juggling balls': 357,
#  'driving tractor': 357,
#  'sword fighting': 357,
#  'push up': 357,
#  'ice climbing': 358,
#  'sailing': 358,
#  'skipping rope': 358,
#  'golf driving': 358,
#  'flipping pancake': 359,
#  'raising eyebrows': 360,
#  'contact juggling': 360,
#  'breakdancing': 360,
#  'tapping guitar': 360,
#  'rock climbing': 361,
#  'snowboarding': 361,
#  'catching or throwing baseball': 361,
#  'eating spaghetti': 361,
#  'canoeing or kayaking': 361,
#  'dancing charleston': 361,
#  'triple jump': 361,
#  'busking': 362,
#  'shaking head': 362,
#  'dodgeball': 362,
#  'playing violin': 362,
#  'presenting weather forecast': 362,
#  'cutting pineapple': 362,
#  'chopping wood': 362,
#  'playing saxophone': 362,
#  'water sliding': 363,
#  'playing badminton': 363,
#  'surfing water': 363,
#  'riding mechanical bull': 363,
#  'situp': 363,
#  'folding napkins': 363,
#  'cooking sausages (not on barbeque)': 363,
#  'playing squash or racquetball': 364,
#  'playing ice hockey': 364,
#  'skydiving': 364,
#  'abseiling': 364,
#  'throwing discus': 364,
#  'wrapping present': 365,
#  'playing paintball': 365,
#  'brushing hair': 365,
#  'long jump': 365,
#  'vacuuming floor': 365,
#  'shuffling feet': 365,
#  'playing didgeridoo': 366,
#  'celebrating': 366,
#  'shoveling snow': 366,
#  'trimming or shaving beard': 366,
#  'headbanging': 367,
#  'bandaging': 367,
#  'riding unicycle': 367,
#  'swing dancing': 367,
#  'battle rope training': 367,
#  'stretching leg': 368,
#  'playing drums': 368,
#  'cheerleading': 368,
#  'somersaulting': 368,
#  'pole vault': 368,
#  'front raises': 368,
#  'marching': 368,
#  'snowkiting': 368,
#  'throwing ball (not baseball or American football)': 369,
#  'bartending': 369,
#  'side kick': 369,
#  'high kick': 369,
#  'plastering': 369,
#  'hurling (sport)': 370,
#  'dunking basketball': 370,
#  'riding scooter': 370,
#  'playing xylophone': 370,
#  'knitting': 370,
#  'hula hooping': 372,
#  'hammer throw': 372,
#  'eating cake': 372,
#  'slacklining': 372,
#  'stretching arm': 373,
#  'cartwheeling': 373,
#  'kitesurfing': 373,
#  'krumping': 373,
#  'playing volleyball': 373,
#  'lunge': 373,
#  'brushing teeth': 373,
#  'playing bagpipes': 373,
#  'parasailing': 373,
#  'watering plants': 373,
#  'reading book': 374,
#  'riding camel': 374,
#  'tying knot (not on a tie)': 375,
#  'dancing macarena': 375,
#  'capoeira': 375,
#  'paragliding': 376,
#  'playing trumpet': 377,
#  'slapping': 377,
#  'bench pressing': 378,
#  'bookbinding': 378,
#  'biking through snow': 379,
#  'roller skating': 379,
#  'playing piano': 380,
#  'gymnastics tumbling': 380,
#  'tobogganing': 381,
#  'mountain climber (exercise)': 382,
#  'doing aerobics': 384,
#  'washing hands': 384,
#  'dancing gangnam style': 386,
#  'snatch weight lifting': 387,
#  'playing organ': 390,
#  'opening bottle (not wine)': 391,
#  'mowing lawn': 391,
#  'spray painting': 392,
#  'swinging on something': 392,
#  'jumpstyle dancing': 396,
#  'skiing slalom': 402}

# %%
label_to_ix = {k:i for i, k in enumerate(label_class)}

# %%
json.dump(label_to_ix, open(basepath + 'mini/class_to_index.json', 'w+'), indent=2)

# %%
for k in mini_train.keys():
    l = mini_train[k]['annotations']['label']
    mini_train[k]['annotations']['label'] = (l, label_to_ix[l])

# %%
list(mini_train.items())[1], len(mini_train)
# Out:
# (('jBacN4yLLyQ',
#   {'annotations': {'label': ('mountain climber (exercise)', 213),
#     'segment': [0.0, 10.0]},
#    'duration': 10.0,
#    'subset': 'train',
#    'url': 'https://www.youtube.com/watch?v=jBacN4yLLyQ',
#    'nb_frames': '300',
#    'hw': (240, 426),
#    'true_duration': '10.010000'}),
#  200000)

# %%
json.dump(mini_train, open(basepath + 'mini/train.json', 'w+'), indent=2)

# %%
mini_val = json.load(open(basepath + 'labels/val.json'))

for k in mini_val.keys():
    l = mini_val[k]['annotations']['label']
    mini_val[k]['annotations']['label'] = (l, label_to_ix[l])

# %%
list(mini_val.items())[1], len(mini_val)
# Out:
# (('--GkrdYZ9Tc',
#   {'annotations': {'label': ('washing feet', 295), 'segment': [0.0, 10.0]},
#    'duration': 10.0,
#    'subset': 'validate',
#    'url': 'https://www.youtube.com/watch?v=--GkrdYZ9Tc',
#    'nb_frames': '240',
#    'hw': [1080, 1920],
#    'true_duration': '10.010667'}),
#  32733)

# %%
json.dump(mini_val, open(basepath + 'mini/val.json', 'w+'), indent=2)
